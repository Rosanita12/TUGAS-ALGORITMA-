# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
jenis_10 = "Angin muson barat"
asal_10 = "belahan bumi selatan terutama Australia"
akibat_10 = "terjadinya musim hujan di Indonesia"
print (jenis_10 + " berasal dari " + asal_10 + " mengakibatkan " + akibat_10)

# %%
print (f"{jenis_10} berasal dari {asal_10} mengakibatkan {akibat_10}")

# %%
nama_10 = input ("Hallo siapa nama anda?:")
pekerjaan_10 = input ("Apa pekerjaan anda?:")
institusi_10 = input ("Dimana anda bekerja?:")
print (f"{nama_10} adalah seorang {pekerjaan_10} di {institusi_10}")

# %%
print ("SELAMAT DATANG DI PROGRAM MENGHITUNG VOLUME BALOK")
p_10 = float (input ("Berapa panjang balok?:"))
l_10 = float (input ("Berapa lebar balok?:"))
t_10 = float (input ("Berapa tinggi balok?:"))

volume_10 = float(p_10)*float(l_10)*float(t_10)

print ("=========================================")
print (f" Jadi luas balok tersebut adalah {volume_10} cm^3")

# %%
print ("BINGUNG MAU MENGHITUNG VOLUME TABUNG DAN LUAS PERMUKAAN TABUNG")

r_10 = float (input("Masukan jari-jari tabung:"))
t_10 = float (input ("Masukan tinggi tabung: "))

Lp_10 = (2 * 22/7 * r_10) *(r_10+ t_10)
V_10 = (22/7* r_10* r_10 * t_10)
                            
print ("========================================================================================================")
print (f"Jadi Volume Tabung adalah {V_10} cm^3 dan Luas Permukaan Tabung adalah {Lp_10} cm^3" )

# %%
planet_10 = "Merkurius, Venus, Bumi, Mars, Jupiter, Saturnus, Uranus, dan Neptunus"
print (planet_10[0:4])
print (planet_10[0:-1])
print (planet_10[:])
print (planet_10[2:-1:3])

# %%
love_10 = "Indonesia is a wonderland "
print(len(love_10))
print("Indonesia" in love_10)
print ("A" in love_10)

# %%
love_10.upper()

# %%
love_10.lower()

# %%
love_10.find("wonderland")

# %%
love_10.find("A")

# %%
print (love_10.upper())
print (love_10.lower())
print (love_10.find("wonderland"))
print (love_10.find("A"))
print (love_10.find("wonderland"))
print (love_10.find("A"))

# %%
print ("HALLO KITA AKAN MAIN TEBAK TEBAKAN YAITU MENEBAK JUMLAH ZODIAK")
p_10 = float(input("Hayo,menurut kamu ada berapa zodiak?: "))

print (p_10>11 and p_10<13)

# %%
print ("YUK KITA MENEBAK ANGKA RANDOM<3")
a_10 = float(input("Hayo,tebak angka berapa: "))
a_10+=2

print(a_10>9 and a_10 < 58)

# %%
print ("Ini adalah kalkulator ajib, kamu tinggal memasukan angka dan hasil dari +,-,*,/, dan ** akan muncul ")
a1_10 = input ("Masukan angka 1: ")
a2_10 = input ("Masukan angka 2: ")

sub_10 = float(a1_10) - float(a2_10)
inc_10 = float(a1_10)+ float(a2_10)
multi_10 = float(a1_10) * float(a2_10)
bagi_10 = float(a1_10)/float(a2_10)
pangkat_10 = float(a1_10)** float(a2_10)
print ("===============================================")
print (f"Hasil pengurangan adalah {sub_10}")
print (f"Hasil pertambahan adalah {inc_10}")
print (f"Hasil perkalian adalah {multi_10}")
print (f"Hasil pembagian adalah {bagi_10}")
print (f"Hasil pangkat adalah {pangkat_10}")
# Out:
# Ini adalah kalkulator ajib, kamu tinggal memasukan angka dan hasil dari +,-,*,/, dan ** akan muncul
# Masukan angka 1:  6
# Masukan angka 2:  4
# ...
# Hasil pengurangan adalah 2.0
# Hasil pertambahan adalah 10.0
# Hasil perkalian adalah 24.0
# Hasil pembagian adalah 1.5
# Hasil pangkat adalah 1296.0
