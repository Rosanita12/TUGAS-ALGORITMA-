# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print("hallo welcome to my world and let's see my coding anyway")
# Out:
# hallo welcome to my world and let's see my coding anyway

# %%
opening_10 = ("hallo, aku adalah program mencetak informasi pengiriman paket sekaligus menghitung biaya pengiriman paket, silahkan isi data dibawah dengan benar")
print (opening_10)
N_10 = input ("Nama Pengirim: ")
N1_10 = input ("Nama Penerima: ")
N2_10 = input ("Alamat Pengirim:")
N3_10 = input ("Alamat Penerima: ")
berat_10 = input ("Masukan berat barang, dalam kg: ")
biaya_10 = 7500 # kilogram
ongkos_kirim = int (berat_10) * (biaya_10) 
print ("\n")
print ("\n")
print ("\n")
print("===============================")
print("Detail Pengiriman Barang")
print("===============================")
print("Nama Pengirim: " + N_10)
print("Nama Penerima: " + N1_10)
print("Alamat Pengirim: " + N2_10)
print("Alamat Penerima: " + N3_10)
print("Berat Barang: " + str(berat_10) + " kg")
print("Ongkos Kirim: Rp. " + str(biaya_10) + " per kg")
print("Total Ongkos Kirim: Rp." + str(ongkos_kirim))
print("===============================")
print("Terima kasih telah menggunakan jasa kami!")
print("===============================")
# Out:
# hallo, aku adalah program mencetak informasi pengiriman paket sekaligus menghitung biaya pengiriman paket, silahkan isi data dibawah dengan benar
# Nama Pengirim:  oca
# Nama Penerima:  nugi
# Alamat Pengirim: bali
# Alamat Penerima:  sby
# Masukan berat barang, dalam kg:  34
# ...
# Detail Pengiriman Barang
# ...
# Nama Pengirim: oca
# Nama Penerima: nugi
# Alamat Pengirim: bali
# Alamat Penerima: sby
# Berat Barang: 34 kg
# Ongkos Kirim: Rp. 7500 per kg
# Total Ongkos Kirim: Rp.255000
# ...
# Terima kasih telah menggunakan jasa kami!
# ...

# %% [markdown]
# print ("yuk kita cek rata-rata pengeluaran minggu ini")

# %%
print ("yuk kita cek rata-rata pengeluaran kita minggu ini")
senin_10 = input ("Pengeluaran hari senin : ")
selasa_10 = input ("Pengeluaran hari selasa ")
rabu_10 = input ("pengeluaran hari rabu: ")
kamis_10 = input ("Pengeluaran hari kamis: ")
jumat_10 = input ("Pengeluaran hari jumat: ")
sabtu_10 = input ("Pengeluaran hari sabtu: ")
minggu_10 = input ("Pengeluaran hari minggu: ")
jumlah_10 = float(senin_10)+ float (selasa_10) + float (rabu_10)+ float (kamis_10) + float (jumat_10)+ float(sabtu_10)+ float (minggu_10)
rata_10 = float(jumlah_10)/7
print("Wah rata-rata pengeluaran minggu ini ternyata: " + str(rata_10))
# Out:
# yuk kita cek rata-rata pengeluaran kita minggu ini
# Pengeluaran hari senin :  67
# Pengeluaran hari selasa  09
# pengeluaran hari rabu:  89
# Pengeluaran hari kamis:  90
# Pengeluaran hari jumat:  80
# Pengeluaran hari sabtu:  89
# Pengeluaran hari minggu:  98
# Wah rata-rata pengeluaran minggu ini ternyata: 74.57142857142857

# %%
opening_10 = ("Bingung mencari mobil apa? Sini aku kasi refrensi")
print(opening_10)
pengguna = input ("Sebelumnya nama kamu siapa? : ")
opening2_10 = ("Welcome " + pengguna + " sekarang pilih dulu jenis mobil di bawah ini")
print (opening2_10)
Pilihan_merek_10 = input ("\n1.Mobil SUV,casual offroad\n2.Mobil MPV,keluarga\n3.Mobil Sedan\n4.Mobil LGGC,bermesin ramah lingkungan dan irit")

if Pilihan_merek_10 == "1":
    M1 = input ("\nA.Toyota\nB.Honda\nC.Mitsubhisi")
    if M1 == "A":
      print ("Saran saya adalah mobil Toyota Fortuner")
    elif M1 == "B":
      print ("Saran saya adalah mobil Honda CR-V" )
    elif M1 == "C":
      print ("Saran saya adalah mobil Pajero Sport")
    else :
      print ("Mohon maaf tidak ada rekomendasi dari merk mobil tersebut")
elif Pilihan_merek_10 == "2":
    M2 = input ("\nA.Toyota\nB.Honda\nC.Mitsubhisi")
    if M2 == "A":
      print ("Saran saya adalah mobil Toyota Kijang Innova" )
    elif M2 == "B":
      print ("Saran saya adalah mobil Honda Mobilio")
    elif M2 == "C":
      print ("Saran saya adalah mobil Mitsubhisi Xpander")
    else :
      print ("Mohon maaf tidak ada rekomendasi dari merk mobil tersebut")

elif Pilihan_merek_10 == "3":
    M3 = input ("\nA.Toyota\nB.Honda\nC.Mitsubhisi")
    if M3 == "A":
      print ("Saran saya adalah mobil Toyota Camry" )
    elif M3 == "B":
      print ("Saran saya adalah mobil Honda Civic")
    elif M3 == "C":
      print ("Saran saya adalah mobil Mitsubhisi Lancer")
    else :
      print ("Mohon maaf tidak ada rekomendasi dari merk mobil tersebut")
    
elif Pilihan_merek_10 == "4":
    M4 = input ("\nA.Toyota\nB.Honda\nC.Mitsubhisi")
    if M4 == "A":
      print ("Saran saya adalah mobil Toyota Agya" )
    elif M4 == "B":
      print ("Saran saya adalah mobil Honda Brio Satya")
    elif M4 == "C":
      print ("Saran saya adalah mobil Mitsubhisi Mirage")
    else :
      print ("Mohon maaf tidak ada rekomendasi dari merk mobil tersebut")
# Out:
# Bingung mencari mobil apa? Sini aku kasi refrensi
# Sebelumnya nama kamu siapa? :  CITRA
# Welcome CITRA sekarang pilih dulu jenis mobil di bawah ini
# 1.Mobil SUV,casual offroad
# 2.Mobil MPV,keluarga
# 3.Mobil Sedan
# 4.Mobil LGGC,bermesin ramah lingkungan dan irit 3
#
# A.Toyota
# B.Honda
# C.Mitsubhisi B
# Saran saya adalah mobil Honda Civic
