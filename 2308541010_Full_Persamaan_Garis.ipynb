# %%
import numpy as np
import matplotlib.pyplot as plt

print('===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis yang melewati 2 titik===============')
#persamaan garis 1 melewati titik (i,j) dan (k,l)
i_10 = float(input("Masukkan nilai x dari titik pertama dari garis pertama adalah "))
j_10 = float(input("Masukkan nilai y dari titik pertama dari garis pertama adalah "))
k_10 = float(input("Masukkan nilai x dari titik kedua dari garis pertama adalah "))
l_10 = float(input("Masukkan nilai y dari titik kedua dari garis pertama adalah "))
#persamaan garis 2 melewati titik (m,n) dan (o,p)
m_10 = float(input("Masukkan nilai x dari titik pertama dari garis kedua adalah "))
n_10 = float(input("Masukkan nilai y dari titik pertama dari garis kedua adalah "))
o_10 = float(input("Masukkan nilai x dari titik kedua dari garis kedua adalah "))
p_10 = float(input("Masukkan nilai y dari titik kedua dari garis kedua adalah "))

#hitung gradien persamaan garis 1 dan 2
m_1_10 = (l_10-j_10)/(k_10-i_10) # Gradien garis pertama
m_2_10 = (p_10-n_10)/(o_10-m_10) # Gradien garis kedua

# Persamaan garis pertama adalah y=m_1(x-i)+j=m_1x-m_1i+j
# Persamaan garis kedua adalah y=m_2(x-m)+n=m_2x-m_2m+n

#hitung titik potong garis pertama dan garis kedua terhadap sumbu y
c_1_10 = -m_1_10*i_10+j_10 # Titik potong garis pertama terhadap sumbu y
c_2_10 = -m_2_10*m_10+n_10 # titik potong garis kedua terhadap sumbu y garis kedua

print("Ini adalah persamaan garis pertamanya y={}x+{}".format(m_1_10,c_1_10))
print("Ini adalah persamaan garis keduanya y={}x+{}".format(m_2_10,c_2_10))

if m_1_10==m_2_10:
    #print("Kedua garis sejajar sehingga kemungkinannya adalah tidak terdapat solusi atau terdapat tak berhingga banyaknya solusi")
    if c_1_10 == c_2_10:
        print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_10*(x-i_10)+j_10,color='blue')
        plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
        plt.show()
    else:
        print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_10*(x-i_10)+j_10,color='blue')
        plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
        plt.show()
else:
    print("Akan terdapat satu titik potong")
    tp_x_10 = (-m_2_10*m_10+n_10+m_1_10*i_10-j_10)/(m_1_10-m_2_10)
    tp_y_10 = m_1_10*(tp_x_10-i_10)+j_10
    print("Titik potong kedua garis adalah ({},{})".format(tp_x_10,tp_y_10))

    x=np.linspace(tp_x_10-5,tp_x_10+5,100)
    plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
    plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
    plt.axvline(x=0,color='grey')
    plt.axhline(y=0,color='grey')
    plt.show()

print('==========================================Terima Kasih==========================================')
# Out:
# ===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis yang melewati 2 titik===============
# Masukkan nilai x dari titik pertama dari garis pertama adalah 2
# Masukkan nilai y dari titik pertama dari garis pertama adalah 2
# Masukkan nilai x dari titik kedua dari garis pertama adalah 4
# Masukkan nilai y dari titik kedua dari garis pertama adalah 4
# Masukkan nilai x dari titik pertama dari garis kedua adalah 2
# Masukkan nilai y dari titik pertama dari garis kedua adalah -2
# Masukkan nilai x dari titik kedua dari garis kedua adalah 4
# Masukkan nilai y dari titik kedua dari garis kedua adalah -4
# Ini adalah persamaan garis pertamanya y=1.0x+0.0
# Ini adalah persamaan garis keduanya y=-1.0x+0.0
# Akan terdapat satu titik potong
# Titik potong kedua garis adalah (0.0,0.0)
# ==========================================Terima Kasih==========================================

# %%
import numpy as np
import matplotlib.pyplot as plt

print('===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis yang melewati 2 titik===============')
#persamaan garis 1 melewati titik (i,j) dan (k,l)
i_10 = float(input("Masukkan nilai x dari titik pertama dari garis pertama adalah "))
j_10 = float(input("Masukkan nilai y dari titik pertama dari garis pertama adalah "))
k_10 = float(input("Masukkan nilai x dari titik kedua dari garis pertama adalah "))
l_10 = float(input("Masukkan nilai y dari titik kedua dari garis pertama adalah "))
#persamaan garis 2 melewati titik (m,n) dan (o,p)
m_10 = float(input("Masukkan nilai x dari titik pertama dari garis kedua adalah "))
n_10 = float(input("Masukkan nilai y dari titik pertama dari garis kedua adalah "))
o_10 = float(input("Masukkan nilai x dari titik kedua dari garis kedua adalah "))
p_10 = float(input("Masukkan nilai y dari titik kedua dari garis kedua adalah "))

#hitung gradien persamaan garis 1 dan 2
m_1_10 = (l_10-j_10)/(k_10-i_10) # Gradien garis pertama
m_2_10 = (p_10-n_10)/(o_10-m_10) # Gradien garis kedua

# Persamaan garis pertama adalah y=m_1(x-i)+j=m_1x-m_1i+j
# Persamaan garis kedua adalah y=m_2(x-m)+n=m_2x-m_2m+n

#hitung titik potong garis pertama dan garis kedua terhadap sumbu y
c_1_10 = -m_1_10*i_10+j_10 # Titik potong garis pertama terhadap sumbu y
c_2_10 = -m_2_10*m_10+n_10 # titik potong garis kedua terhadap sumbu y garis kedua

print("Ini adalah persamaan garis pertamanya y={}x+{}".format(m_1_10,c_1_10))
print("Ini adalah persamaan garis keduanya y={}x+{}".format(m_2_10,c_2_10))

if m_1_10==m_2_10:
    #print("Kedua garis sejajar sehingga kemungkinannya adalah tidak terdapat solusi atau terdapat tak berhingga banyaknya solusi")
    if c_1_10 == c_2_10:
        print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
        plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
        plt.show()
    else:
        print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
        plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
        plt.show()
else:
    print("Akan terdapat satu titik potong")
    tp_x_10 = (-m_2_10*m_10+n_10+m_1_10*i_10-j_10)/(m_1_10-m_2_10)
    tp_y_10 = m_1_10*(tp_x_10-i_10)+j_10
    print("Titik potong kedua garis adalah ({},{})".format(tp_x_10,tp_y_10))

    x=np.linspace(tp_x_10-5,tp_x_10+5,100)
    plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
    plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
    plt.axvline(x=0,color='grey')
    plt.axhline(y=0,color='grey')
    plt.show()

print('==========================================Terima Kasih==========================================')
# Out:
# ===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis yang melewati 2 titik===============
# Masukkan nilai x dari titik pertama dari garis pertama adalah 0
# Masukkan nilai y dari titik pertama dari garis pertama adalah 2
# Masukkan nilai x dari titik kedua dari garis pertama adalah 2
# Masukkan nilai y dari titik kedua dari garis pertama adalah 6
# Masukkan nilai x dari titik pertama dari garis kedua adalah 4
# Masukkan nilai y dari titik pertama dari garis kedua adalah 10
# Masukkan nilai x dari titik kedua dari garis kedua adalah 6
# Masukkan nilai y dari titik kedua dari garis kedua adalah 14
# Ini adalah persamaan garis pertamanya y=2.0x+2.0
# Ini adalah persamaan garis keduanya y=2.0x+2.0
# Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi
# ==========================================Terima Kasih==========================================

# %%
import numpy as np
import matplotlib.pyplot as plt

print('===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis yang melewati 2 titik===============')
#persamaan garis 1 melewati titik (i,j) dan (k,l)
i_10 = float(input("Masukkan nilai x dari titik pertama dari garis pertama adalah "))
j_10 = float(input("Masukkan nilai y dari titik pertama dari garis pertama adalah "))
k_10 = float(input("Masukkan nilai x dari titik kedua dari garis pertama adalah "))
l_10 = float(input("Masukkan nilai y dari titik kedua dari garis pertama adalah "))
#persamaan garis 2 melewati titik (m,n) dan (o,p)
m_10 = float(input("Masukkan nilai x dari titik pertama dari garis kedua adalah "))
n_10 = float(input("Masukkan nilai y dari titik pertama dari garis kedua adalah "))
o_10 = float(input("Masukkan nilai x dari titik kedua dari garis kedua adalah "))
p_10 = float(input("Masukkan nilai y dari titik kedua dari garis kedua adalah "))

#hitung gradien persamaan garis 1 dan 2
m_1_10 = (l_10-j_10)/(k_10-i_10) # Gradien garis pertama
m_2_10 = (p_10-n_10)/(o_10-m_10) # Gradien garis kedua

# Persamaan garis pertama adalah y=m_1(x-i)+j=m_1x-m_1i+j
# Persamaan garis kedua adalah y=m_2(x-m)+n=m_2x-m_2m+n

#hitung titik potong garis pertama dan garis kedua terhadap sumbu y
c_1_10 = -m_1_10*i_10+j_10 # Titik potong garis pertama terhadap sumbu y
c_2_10 = -m_2_10*m_10+n_10 # titik potong garis kedua terhadap sumbu y garis kedua

print("Ini adalah persamaan garis pertamanya y={}x+{}".format(m_1_10,c_1_10))
print("Ini adalah persamaan garis keduanya y={}x+{}".format(m_2_10,c_2_10))

if m_1_10==m_2_10:
    #print("Kedua garis sejajar sehingga kemungkinannya adalah tidak terdapat solusi atau terdapat tak berhingga banyaknya solusi")
    if c_1_10 == c_2_10:
        print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
        plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
        plt.show()
    else:
        print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")
        x=np.linspace(-5,5,100)
        plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
        plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
        plt.show()
else:
    print("Akan terdapat satu titik potong")
    tp_x_10 = (-m_2_10*m_10+n_10+m_1_10*i_10-j_10)/(m_1_10-m_2_10)
    tp_y_10 = m_1_10*(tp_x_10-i_10)+j_10
    print("Titik potong kedua garis adalah ({},{})".format(tp_x_10,tp_y_10))

    x=np.linspace(tp_x_10-5,tp_x_10+5,100)
    plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
    plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
    plt.axvline(x=0,color='grey')
    plt.axhline(y=0,color='grey')
    plt.show()

print('==========================================Terima Kasih==========================================')
# Out:
# ===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis yang melewati 2 titik===============
# Masukkan nilai x dari titik pertama dari garis pertama adalah 0
# Masukkan nilai y dari titik pertama dari garis pertama adalah 2
# Masukkan nilai x dari titik kedua dari garis pertama adalah 2
# Masukkan nilai y dari titik kedua dari garis pertama adalah 6
# Masukkan nilai x dari titik pertama dari garis kedua adalah 0
# Masukkan nilai y dari titik pertama dari garis kedua adalah -6
# Masukkan nilai x dari titik kedua dari garis kedua adalah 2
# Masukkan nilai y dari titik kedua dari garis kedua adalah -2
# Ini adalah persamaan garis pertamanya y=2.0x+2.0
# Ini adalah persamaan garis keduanya y=2.0x+-6.0
# Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.
# ==========================================Terima Kasih==========================================

# %%
print('===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis jika diketahui gradien dan titik yang dilewati===============')
print("Masing-masing garis diketahui gradien dan titik yang dilewati.")
# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (i,j)
m1_10 = float(input("Masukkan gradien dari garis pertama: "))
i_10 = float(input("Msukkan nilai x dari titik yang dilewati oleh garis pertama: "))
j_10 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis pertama: "))

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (k,l)
m2_10 = float(input("Masukkan gradien dari garis kedua: "))
k_10 = float(input("Masukkan nilai x dari titik yang dilewati oleh garis kedua: "))
l_10 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis kedua: "))

# Menghitung konstanta dari masing-masing persamaan garis
c1_10 = -m1_10*i_10+j_10
c2_10 = -m2_10*k_10+l_10

    # Memeriksa apakah kedua garis sejajar atau tidak
if m1_10 == m2_10:
      # print("Kedua garis sejajar ")
        if c1_10 == c2_10:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Plotting the lines
        x = np.linspace(-10, 10, 400)
        y1_10 = m1_10*(x-i_10)+ j_10
        y2_10 = m2_10*(x-k_10) + l_10
        plt.plot(x, y1_10, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_10, i_10, j_10), color='brown')
        plt.plot(x, y2_10, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_10, k_10, l_10), color='green')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
else:
        # Menghitung titik potong dari kedua garis
        tp_x_10 = (c2_10 - c1_10) / (m1_10 - m2_10)
        tp_y_10 = m1_10 * (tp_x_10 - i_10) + j_10
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tp_x_10, tp_y_10))

        # Plotting the lines
        x = np.linspace(tp_x_10-10, tp_x_10+10, 400)
        y1_10 = m1_10*(x-i_10)+j_10
        y2_10 = m2_10*(x-k_10)+l_10
        plt.plot(x, y1_10, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_10, i_10, j_10), color='brown')
        plt.plot(x, y2_10, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_10, k_10, l_10), color='green')
        plt.scatter(tp_x_10, tp_y_10, color='red', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
print('==========================================Terima Kasih==========================================')
# Out:
# ===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis jika diketahui gradien dan titik yang dilewati===============
# Masing-masing garis diketahui gradien dan titik yang dilewati.
# Masukkan gradien dari garis pertama: 2
# Msukkan nilai x dari titik yang dilewati oleh garis pertama: 2
# Masukkan nilai y dari titik yang dilewati oleh garis pertama: 2
# Masukkan gradien dari garis kedua: -2
# Masukkan nilai x dari titik yang dilewati oleh garis kedua: 0
# Masukkan nilai y dari titik yang dilewati oleh garis kedua: 2
# Titik potong kedua garis adalah (1.000,0.000)
# ==========================================Terima Kasih==========================================

# %%
print('===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis jika diketahui gradien dan titik yang dilewati===============')
print("Masing-masing garis diketahui gradien dan titik yang dilewati.")
# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (i,j)
m1_10 = float(input("Masukkan gradien dari garis pertama: "))
i_10 = float(input("Msukkan nilai x dari titik yang dilewati oleh garis pertama: "))
j_10 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis pertama: "))

# Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (k,l)
m2_10 = float(input("Masukkan gradien dari garis kedua: "))
k_10 = float(input("Masukkan nilai x dari titik yang dilewati oleh garis kedua: "))
l_10 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis kedua: "))

# Menghitung konstanta dari masing-masing persamaan garis
c1_10 = -m1_10*i_10+j_10
c2_10 = -m2_10*k_10+l_10

    # Memeriksa apakah kedua garis sejajar atau tidak
if m1_10 == m2_10:
      # print("Kedua garis sejajar ")
        if c1_10 == c2_10:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Plotting the lines
        x = np.linspace(-10, 10, 400)
        y1_10 = m1_10*(x-i_10)+ j_10
        y2_10 = m2_10*(x-k_10) + l_10
        plt.plot(x, y1_10, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_10, i_10, j_10), color='brown')
        plt.plot(x, y2_10, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_10, k_10, l_10), color='green')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
else:
        # Menghitung titik potong dari kedua garis
        tp_x_10 = (c2_10 - c1_10) / (m1_10 - m2_10)
        tp_y_10 = m1_10 * (tp_x_10 - i_10) + j_10
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tp_x_10, tp_y_10))

        # Plotting the lines
        x = np.linspace(tp_x_10-10, tp_x_10+10, 400)
        y1_10 = m1_10*(x-i_10)+j_10
        y2_10 = m2_10*(x-k_10)+l_10
        plt.plot(x, y1_10, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_10, i_10, j_10), color='brown')
        plt.plot(x, y2_10, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_10, k_10, l_10), color='green')
        plt.scatter(tp_x_10, tp_y_10, color='red', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()

print('==========================================Terima Kasih==========================================')
# Out:
# ===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis jika diketahui gradien dan titik yang dilewati===============
# Masing-masing garis diketahui gradien dan titik yang dilewati.
# Masukkan gradien dari garis pertama: 6
# Msukkan nilai x dari titik yang dilewati oleh garis pertama: 0
# Masukkan nilai y dari titik yang dilewati oleh garis pertama: 3
# Masukkan gradien dari garis kedua: 6
# Masukkan nilai x dari titik yang dilewati oleh garis kedua: 9
# Masukkan nilai y dari titik yang dilewati oleh garis kedua: 21
# Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.
# ==========================================Terima Kasih==========================================

# %%
print('===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis jika mengikuti bentuk persamaan ax+by=c dan dx+ey=f===============')
print("Kedua garis memenuhi persamaan berbentuk ax+by=c dan dx+ey=f.")
#Masukkan koefisien dan konstanta dari x dan y dari garis pertama dan kedua
i_10 = float(input("Masukkan koefisien dari x pada garis pertama adalah "))
j_10 = float(input("Masukkan koefisien dari y pada garis pertama adalah "))
k_10 = float(input("Masukkan konstanta dari garis pertama adalah "))

l_10 = float(input("Masukkan koefisien dari x pada garis kedua adalah "))
m_10 = float(input("Masukkan koefisien dari y pada garis kedua adalah "))
n_10 = float(input("Masukkan konstanta dari garis kedua adalah "))

# Menghitung determinan utama
D_10 = i_10*m_10 - j_10*l_10

if D_10 == 0:
        print ("Garis-garis tersebut paralel atau berimpit, sehingga tidak memiliki titik potong yang unik.")
          # Menyiapkan data untuk plotting
        x_vals_10 = np.linspace(-10, 10, 400)
        y_vals1_10 = (k_10 - i_10* x_vals) / j_10
        y_vals2_10 = (n_10 - l_10 * x_vals) / m_10

        # Plot garis pertama
        plt.plot(x_vals_10, y_vals1_10, label=f'{i_10}x + {j_10}y = {k_10}')

        # Plot garis kedua
        plt.plot(x_vals_10, y_vals2_10, label=f'{l_10}x + {m_10}y = {n_10}')

        # Plot titik potong
        plt.plot(x, y, 'ro')  # 'ro' means red color, circle marker
        plt.text(x, y, f'({x:.2f}, {y:.2f})', fontsize=12, ha='right')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah persamaan garisnya')

        # Menampilkan plot
        plt.show()
else:
        # Menghitung determinan untuk x dan y
        Dx_10 = k_10*m_10 - j_10*n_10
        Dy_10 = i_10*n_10 - k_10*l_10
        # Menemukan solusi untuk x dan y
        x = Dx_10 /D_10
        y = Dy_10 /D_10
        print(f"Titik potong dari dua garis adalah: x = {x}, y = {y}")
        # Menyiapkan data untuk plotting
        x_vals_10 = np.linspace(-10, 10, 400)
        y_vals1_10 = (k_10 - i_10 * x_vals_10) / j_10
        y_vals2_10 = (n_10 - l_10 * x_vals_10) / m_10

        # Plot garis pertama
        plt.plot(x_vals_10, y_vals1_10, label=f'{i_10}x + {j_10}y = {k_10}')

        # Plot garis kedua
        plt.plot(x_vals_10, y_vals2_10, label=f'{l_10}x + {m_10}y = {n_10}')

        # Plot titik potong
        plt.plot(x, y, 'ro')  # 'ro' means red color, circle marker
        plt.text(x, y, f'({x:.2f}, {y:.2f})', fontsize=12, ha='right')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Grafik Dua Garis dan Titik Potongnya')

        # Menampilkan plot
        plt.show()
print('==========================================Terima Kasih==========================================')
# Out:
# ===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis jika mengikuti bentuk persamaan ax+by=c dan dx+ey=f===============
# Kedua garis memenuhi persamaan berbentuk ax+by=c dan dx+ey=f.
# Masukkan koefisien dari x pada garis pertama adalah 2
# Masukkan koefisien dari y pada garis pertama adalah 4
# Masukkan konstanta dari garis pertama adalah 6
# Masukkan koefisien dari x pada garis kedua adalah 6
# Masukkan koefisien dari y pada garis kedua adalah 4
# Masukkan konstanta dari garis kedua adalah 2
# Titik potong dari dua garis adalah: x = -1.0, y = 2.0
# ==========================================Terima Kasih==========================================

# %%
print('===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis jika mengikuti bentuk persamaan ax+by=c dan dx+ey=f===============')
print("Kedua garis memenuhi persamaan berbentuk ax+by=c dan dx+ey=f.")
#Masukkan koefisien dan konstanta dari x dan y dari garis pertama dan kedua
i_10 = float(input("Masukkan koefisien dari x pada garis pertama adalah "))
j_10 = float(input("Masukkan koefisien dari y pada garis pertama adalah "))
k_10 = float(input("Masukkan konstanta dari garis pertama adalah "))

l_10 = float(input("Masukkan koefisien dari x pada garis kedua adalah "))
m_10 = float(input("Masukkan koefisien dari y pada garis kedua adalah "))
n_10 = float(input("Masukkan konstanta dari garis kedua adalah "))

def solve_linear_equations(i_10,j_10,k_10,l_10,m_10,n_10):
    # Membentuk matriks koefisien
    A_10 = np.array([[i_10, j_10],
                  [l_10, m_10]])

    # Membentuk matriks konstanta
    B_10 = np.array([k_10, n_10])

    # Menghitung determinan dari matriks A
    det_A_10 = np.linalg.det(A_10)

    if det_A_10 != 0:
        # Solusi tunggal
        solution = np.linalg.solve(A_10, B_10)
        result = f"Solusi tunggal: x = {solution[0]}, y = {solution[1]}"
        plot_lines_and_solution(i_10,j_10,k_10,l_10,m_10,n_10,solution)
        return result
    else:
        # Cek apakah sistem konsisten
        augmented_matrix_10 = np.array([[i_10, j_10, k_10],
                                     [l_10, m_10, n_10]])
        rank_A_10 = np.linalg.matrix_rank(A_10)
        rank_augmented_10 = np.linalg.matrix_rank(augmented_matrix_10)

        if rank_A_10 == rank_augmented_10:
            result = "Tak terbatas solusi"
            plot_lines_and_solution(i_10,j_10,k_10,l_10,m_10,n_10,None)
            return result
        else:
            result = "Tidak ada solusi"
            plot_lines_and_solution(i_10,j_10,k_10,l_10,m_10,n_10,None)
            return result_

def plot_lines_and_solution(i_10,j_10,k_10,l_10,m_10,n_10,solution):
    # Menentukan rentang nilai x
    x_values_10 = np.linspace(-10, 10, 400)

    # Menghitung nilai y untuk masing-masing persamaan
    y1_values_10 = (k_10 - i_10 * x_values_10) / j_10
    y2_values_10 = (n_10 - l_10 * x_values_10) / m_10

    plt.figure(figsize=(8, 6))

    # Plot garis pertama
    plt.plot(x_values_10, y1_values_10, label=f'{i_10}x + {j_10}y = {k_10}')

    # Plot garis kedua
    plt.plot(x_values_10, y2_values_10, label=f'{l_10}x + {m_10}y = {n_10}')

    # Jika ada solusi tunggal, plot titik potong
    if solution is not None:
        plt.plot(solution[0], solution[1], 'ro')  # Titik potong berwarna merah
        plt.annotate(f'({solution[0]:.2f}, {solution[1]:.2f})', xy=(solution[0], solution[1]), xytext=(solution[0] + 1, solution[1]))

    plt.axhline(0, color='black',linewidth=0.5)
    plt.axvline(0, color='black',linewidth=0.5)
    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.legend()
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Grafik Persamaan Linear')
    plt.show()


result = solve_linear_equations(i_10,j_10,k_10,l_10,m_10,n_10)
print(result)
print('=============================TERIMA KASIH==================================')
# Out:
# ===============Selamat datang di pemrograman mencari solusi dari bentuk persamaan garis jika mengikuti bentuk persamaan ax+by=c dan dx+ey=f===============
# Kedua garis memenuhi persamaan berbentuk ax+by=c dan dx+ey=f.
# Masukkan koefisien dari x pada garis pertama adalah 2
# Masukkan koefisien dari y pada garis pertama adalah 4
# Masukkan konstanta dari garis pertama adalah 6
# Masukkan koefisien dari x pada garis kedua adalah 6
# Masukkan koefisien dari y pada garis kedua adalah 8
# Masukkan konstanta dari garis kedua adalah 10
# Solusi tunggal: x = -1.0, y = 2.0
# =============================TERIMA KASIH==================================

# %%
# 1. Garis melewati 2 titik
# 2. Garis diketahui gradien dan titik yang dilewati
# 3. Mengikuti persamaan garis ax+by=c dan dx+ey=f

import numpy as np
import matplotlib.pyplot as plt
print('-----------------Mari mencari titik potong dari dua garis yang memenuhi salah satu dari ketiga kasus di bawah ini!-----------------')
kasus_10 = float(input("Kasus berapakah yang kamu ingin kerjakan? "))

if kasus_10 == 1:
    # Masukkan titik garis pertama (i,j) dan (k,l)
    i_10 = float(input("Masukkan nilai x dari titik pertama dari garis pertama adalah "))
    j_10 = float(input("Masukkan nilai y dari titik pertama dari garis pertama adalah "))
    k_10 = float(input("Masukkan nilai x dari titik kedua dari garis pertama adalah "))
    l_10 = float(input("Masukkan nilai y dari titik kedua dari garis pertama adalah "))

    # Masukkan titik garis kedua (m,n) dan (o,p)
    m_10 = float(input("Masukkan nilai x dari titik pertama dari garis kedua adalah "))
    n_10 = float(input("Masukkan nilai y dari titik pertama dari garis kedua adalah "))
    o_10 = float(input("Masukkan nilai x dari titik kedua dari garis kedua adalah "))
    p_10 = float(input("Masukkan nilai y dari titik kedua dari garis kedua adalah "))

    # Gradien garis pertama
    m_1_10 = (l_10-j_10)/(k_10-i_10)
    # Gradien garis kedua
    m_2_10 = (p_10-n_10)/(o_10-m_10)

    # Persamaan garis pertama adalah y=m1(x-i)+j => m1*x-m1*i+j
    # Persamaan garis kedua adalah y=m2(x-m)+n => m2*x-m2*m+n

    # Titik potong garis pertama terhadap sumbu y
    c_1_10 = -m_1_10*i_10+j_10
    # Titik potong garis kedua terhadap sumbu y garis kedua
    c_2_10 = -m_2_10*m_10+n_10

    print("Persamaan garis pertama adalah y={}x+{}".format(m_1_10, c_1_10))
    print("Persamaan garis kedua adalah y={}x+{}".format(m_2_10, c_2_10))

    if m_1_10 == m_2_10:
        # print("Kedua garis sejajar sehingga kemungkinan yang terjadi adalah tidak terdapat solusi atau terdapat tidak berhingga banyaknya solusi")
        if c_1_10 == c_2_10:
            print("Kedua garis akan berhimpitan sehingga terdapat tidak berhingga banyaknya solusi")
            x = np.linspace(-9, 9, 100)
            plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
            plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
            plt.show()
        else:
            print("Kedua garis tidak akan berpotongan, sehingga tidak akan terdapat solusi")
            x = np.linspace(-9, 9, 100)
            plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
            plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
            plt.show()
    else:
        print("Akan terdapat satu titik potong")
        tp_x_10 = (-m_2_10*m_10+n_10+m_1_10*i_10-j_10)/(m_1_10-m_2_10)
        tp_y_10 = m_1_10*(tp_x_10-i_10)+j_10
        print("Titik potong kedua garis adalah ({},{})".format(tp_x_10,tp_y_10))

        x=np.linspace(tp_x_10-5,tp_x_10+9,100)
        plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
        plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
        plt.axvline(x=0,color='grey')
        plt.axhline(y=0,color='grey')
        plt.show()

elif kasus_10 == 2:
    # Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (i,j)
    m1_10 = float(input("Masukkan gradien dari garis pertama: "))
    i_10 = float(input("Masukkan nilai x dari titik yang dilewati oleh garis pertama: "))
    j_10 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis pertama: "))


    # Masukkan nilai gradien persamaan garis kedua dan titik yang diketahui (k,l)
    m2_10 = float(input("Masukkan gradien dari garis kedua: "))
    k_10 = float(input("Masukkan nilai x dari titik yang dilewati oleh garis kedua: "))
    l_10 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis kedua: "))


    # Menghitung konstanta dari masing-masing persamaan garis
    c1_10 = -m1_10*i_10+j_10
    c2_10 = -m2_10*k_10+l_10

    # Memeriksa apakah kedua garis sejajar atau tidak
    if m1_10 == m2_10:
        # print("Kedua garis sejajar ")
        if c1_10 == c2_10:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Plotting the lines
        x = np.linspace(-10, 10, 400)
        y1_10 = m1_10*(x-i_10)+ j_10
        y2_10 = m2_10*(x-k_10) + l_10
        plt.plot(x, y1_10, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_10, i_10, j_10), color='brown')
        plt.plot(x, y2_10, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_10, k_10, l_10), color='green')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
    else:
        # Menghitung titik potong dari kedua garis
        tp_x_10 = (c2_10 - c1_10) / (m1_10 - m2_10)
        tp_y_10 = m1_10 * (tp_x_10 - i_10) + j_10
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tp_x_10, tp_y_10))

        # Plotting the lines
        x = np.linspace(tp_x_10-10, tp_x_10+10, 400)
        y1_10 = m1_10*(x-i_10)+j_10
        y2_10 = m2_10*(x-k_10)+l_10
        plt.plot(x, y1_10, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_10, i_10, j_10), color='brown')
        plt.plot(x, y2_10, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_10, k_10, l_10), color='green')
        plt.scatter(tp_x_10, tp_y_10, color='red', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()

elif kasus_10 == 3:
    print("Kedua garis memenuhi persamaan berbentuk ax+by=c dan dx+ey=f.")
    #Masukkan koefisien dan konstanta dari x dan y dari garis pertama dan kedua
    i_10 = float(input("Masukkan koefisien dari x pada garis pertama adalah "))
    j_10 = float(input("Masukkan koefisien dari y pada garis pertama adalah "))
    k_10 = float(input("Masukkan konstanta dari garis pertama adalah "))

    l_10 = float(input("Masukkan koefisien dari x pada garis kedua adalah "))
    m_10 = float(input("Masukkan koefisien dari y pada garis kedua adalah "))
    n_10 = float(input("Masukkan konstanta dari garis kedua adalah "))

    # Menghitung determinan utama
    D_10 = i_10*m_10 - j_10*l_10

    if D_10 == 0:
        print ("Garis-garis tersebut paralel atau berimpit, sehingga tidak memiliki titik potong yang unik.")
          # Menyiapkan data untuk plotting
        x_vals_10 = np.linspace(-10, 10, 400)
        y_vals1_10 = (k_10 - i_10* x_vals) / j_10
        y_vals2_10 = (n_10 - l_10 * x_vals) / m_10

        # Plot garis pertama
        plt.plot(x_vals_10, y_vals1_10, label=f'{i_10}x + {j_10}y = {k_10}')

        # Plot garis kedua
        plt.plot(x_vals_10, y_vals2_10, label=f'{l_10}x + {m_10}y = {n_10}')

        # Plot titik potong
        plt.plot(x, y, 'ro')  # 'ro' means red color, circle marker
        plt.text(x, y, f'({x:.2f}, {y:.2f})', fontsize=12, ha='right')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah persamaan garisnya')

        # Menampilkan plot
        plt.show()
    else:
        # Menghitung determinan untuk x dan y
        Dx_10 = k_10*m_10 - j_10*n_10
        Dy_10 = i_10*n_10 - k_10*l_10
        # Menemukan solusi untuk x dan y
        x = Dx_10 /D_10
        y = Dy_10 /D_10
        print(f"Titik potong dari dua garis adalah: x = {x}, y = {y}")
        # Menyiapkan data untuk plotting
        x_vals_10 = np.linspace(-10, 10, 400)
        y_vals1_10 = (k_10 - i_10 * x_vals_10) / j_10
        y_vals2_10 = (n_10 - l_10 * x_vals_10) / m_10

        # Plot garis pertama
        plt.plot(x_vals_10, y_vals1_10, label=f'{i_10}x + {j_10}y = {k_10}')

        # Plot garis kedua
        plt.plot(x_vals_10, y_vals2_10, label=f'{l_10}x + {m_10}y = {n_10}')

        # Plot titik potong
        plt.plot(x, y, 'ro')  # 'ro' means red color, circle marker
        plt.text(x, y, f'({x:.2f}, {y:.2f})', fontsize=12, ha='right')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Grafik Dua Garis dan Titik Potongnya')

        # Menampilkan plot
        plt.show()

else:
  print("Mohon maaf, hanya terdapat 3 kasus saja. Mohon masukkan 1, 2 atau 3 saja ya!.")

print("==================================================TERIMA KASIH=================================================")
# Out:
# -----------------Mari mencari titik potong dari dua garis yang memenuhi salah satu dari ketiga kasus di bawah ini!-----------------
# Kasus berapakah yang kamu ingin kerjakan? 1
# Masukkan nilai x dari titik pertama dari garis pertama adalah 0
# Masukkan nilai y dari titik pertama dari garis pertama adalah 2
# Masukkan nilai x dari titik kedua dari garis pertama adalah 2
# Masukkan nilai y dari titik kedua dari garis pertama adalah 6
# Masukkan nilai x dari titik pertama dari garis kedua adalah 0
# Masukkan nilai y dari titik pertama dari garis kedua adalah -6
# Masukkan nilai x dari titik kedua dari garis kedua adalah 2
# Masukkan nilai y dari titik kedua dari garis kedua adalah -2
# Persamaan garis pertama adalah y=2.0x+2.0
# Persamaan garis kedua adalah y=2.0x+-6.0
# Kedua garis tidak akan berpotongan, sehingga tidak akan terdapat solusi
# ==================================================TERIMA KASIH=================================================

# %%
import numpy as np
import matplotlib.pyplot as plt
print('-----------------Mari mencari titik potong dari dua garis yang memenuhi salah satu dari ketiga kasus di bawah ini!-----------------')
kasus_10 = float(input("Kasus berapakah yang kamu ingin kerjakan? "))

if kasus_10 == 1:
    # Masukkan titik garis pertama (i,j) dan (k,l)
    i_10 = float(input("Masukkan nilai x dari titik pertama dari garis pertama adalah "))
    j_10 = float(input("Masukkan nilai y dari titik pertama dari garis pertama adalah "))
    k_10 = float(input("Masukkan nilai x dari titik kedua dari garis pertama adalah "))
    l_10 = float(input("Masukkan nilai y dari titik kedua dari garis pertama adalah "))

    # Masukkan titik garis kedua (m,n) dan (o,p)
    m_10 = float(input("Masukkan nilai x dari titik pertama dari garis kedua adalah "))
    n_10 = float(input("Masukkan nilai y dari titik pertama dari garis kedua adalah "))
    o_10 = float(input("Masukkan nilai x dari titik kedua dari garis kedua adalah "))
    p_10 = float(input("Masukkan nilai y dari titik kedua dari garis kedua adalah "))

    # Gradien garis pertama
    m_1_10 = (l_10-j_10)/(k_10-i_10)
    # Gradien garis kedua
    m_2_10 = (p_10-n_10)/(o_10-m_10)

    # Persamaan garis pertama adalah y=m1(x-i)+j => m1*x-m1*i+j
    # Persamaan garis kedua adalah y=m2(x-m)+n => m2*x-m2*m+n

    # Titik potong garis pertama terhadap sumbu y
    c_1_10 = -m_1_10*i_10+j_10
    # Titik potong garis kedua terhadap sumbu y garis kedua
    c_2_10 = -m_2_10*m_10+n_10

    print("Persamaan garis pertama adalah y={}x+{}".format(m_1_10, c_1_10))
    print("Persamaan garis kedua adalah y={}x+{}".format(m_2_10, c_2_10))

    if m_1_10 == m_2_10:
        # print("Kedua garis sejajar sehingga kemungkinan yang terjadi adalah tidak terdapat solusi atau terdapat tidak berhingga banyaknya solusi")
        if c_1_10 == c_2_10:
            print("Kedua garis akan berhimpitan sehingga terdapat tidak berhingga banyaknya solusi")
            x = np.linspace(-9, 9, 100)
            plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
            plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
            plt.show()
        else:
            print("Kedua garis tidak akan berpotongan, sehingga tidak akan terdapat solusi")
            x = np.linspace(-9, 9, 100)
            plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
            plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
            plt.show()
    else:
        print("Akan terdapat satu titik potong")
        tp_x_10 = (-m_2_10*m_10+n_10+m_1_10*i_10-j_10)/(m_1_10-m_2_10)
        tp_y_10 = m_1_10*(tp_x_10-i_10)+j_10
        print("Titik potong kedua garis adalah ({},{})".format(tp_x_10,tp_y_10))

        x=np.linspace(tp_x_10-5,tp_x_10+9,100)
        plt.plot(x,m_1_10*(x-i_10)+j_10,color='brown')
        plt.plot(x,m_2_10*(x-m_10)+n_10,color='green')
        plt.axvline(x=0,color='grey')
        plt.axhline(y=0,color='grey')
        plt.show()

elif kasus_10 == 2:
    # Masukkan nilai gradien persamaan garis pertama dan titik yang diketahui (i,j)
    m1_10 = float(input("Masukkan gradien dari garis pertama: "))
    i_10 = float(input("Masukkan nilai x dari titik yang dilewati oleh garis pertama: "))
    j_10 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis pertama: "))


    # Masukkan nilai gradien persamaan garis kedua dan titik yang diketahui (k,l)
    m2_10 = float(input("Masukkan gradien dari garis kedua: "))
    k_10 = float(input("Masukkan nilai x dari titik yang dilewati oleh garis kedua: "))
    l_10 = float(input("Masukkan nilai y dari titik yang dilewati oleh garis kedua: "))


    # Menghitung konstanta dari masing-masing persamaan garis
    c1_10 = -m1_10*i_10+j_10
    c2_10 = -m2_10*k_10+l_10

    # Memeriksa apakah kedua garis sejajar atau tidak
    if m1_10 == m2_10:
        # print("Kedua garis sejajar ")
        if c1_10 == c2_10:
            print("Kedua garis berhimpitan sehingga akan terdapat tak berhingga banyaknya solusi")
        else:
            print("Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.")

        # Plotting the lines
        x = np.linspace(-10, 10, 400)
        y1_10 = m1_10*(x-i_10)+ j_10
        y2_10 = m2_10*(x-k_10) + l_10
        plt.plot(x, y1_10, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_10, i_10, j_10), color='brown')
        plt.plot(x, y2_10, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_10, k_10, l_10), color='green')
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()
    else:
        # Menghitung titik potong dari kedua garis
        tp_x_10 = (c2_10 - c1_10) / (m1_10 - m2_10)
        tp_y_10 = m1_10 * (tp_x_10 - i_10) + j_10
        print("Titik potong kedua garis adalah ({:.3f},{:.3f})".format(tp_x_10, tp_y_10))

        # Plotting the lines
        x = np.linspace(tp_x_10-10, tp_x_10+10, 400)
        y1_10 = m1_10*(x-i_10)+j_10
        y2_10 = m2_10*(x-k_10)+l_10
        plt.plot(x, y1_10, label="Garis 1 (y={:.3f}(x-{:.3f})+{:.3f})".format(m1_10, i_10, j_10), color='brown')
        plt.plot(x, y2_10, label="Garis 2 (y={:.3f}(x-{:.3f})+{:.3f})".format(m2_10, k_10, l_10), color='green')
        plt.scatter(tp_x_10, tp_y_10, color='red', zorder=5)
        plt.axvline(x=0, color='black')
        plt.axhline(y=0, color='black')
        plt.legend(loc='best')
        plt.show()

elif kasus_10 == 3:
    print("Kedua garis memenuhi persamaan berbentuk ax+by=c dan dx+ey=f.")
    #Masukkan koefisien dan konstanta dari x dan y dari garis pertama dan kedua
    i_10 = float(input("Masukkan koefisien dari x pada garis pertama adalah "))
    j_10 = float(input("Masukkan koefisien dari y pada garis pertama adalah "))
    k_10 = float(input("Masukkan konstanta dari garis pertama adalah "))

    l_10 = float(input("Masukkan koefisien dari x pada garis kedua adalah "))
    m_10 = float(input("Masukkan koefisien dari y pada garis kedua adalah "))
    n_10 = float(input("Masukkan konstanta dari garis kedua adalah "))

    # Menghitung determinan utama
    D_10 = i_10*m_10 - j_10*l_10

    if D_10 == 0:
        print ("Garis-garis tersebut paralel atau berimpit, sehingga tidak memiliki titik potong yang unik.")
          # Menyiapkan data untuk plotting
        x_vals_10 = np.linspace(-10, 10, 400)
        y_vals1_10 = (k_10 - i_10* x_vals) / j_10
        y_vals2_10 = (n_10 - l_10 * x_vals) / m_10

        # Plot garis pertama
        plt.plot(x_vals_10, y_vals1_10, label=f'{i_10}x + {j_10}y = {k_10}')

        # Plot garis kedua
        plt.plot(x_vals_10, y_vals2_10, label=f'{l_10}x + {m_10}y = {n_10}')

        # Plot titik potong
        plt.plot(x, y, 'ro')  # 'ro' means red color, circle marker
        plt.text(x, y, f'({x:.2f}, {y:.2f})', fontsize=12, ha='right')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Inilah persamaan garisnya')

        # Menampilkan plot
        plt.show()
    else:
        # Menghitung determinan untuk x dan y
        Dx_10 = k_10*m_10 - j_10*n_10
        Dy_10 = i_10*n_10 - k_10*l_10
        # Menemukan solusi untuk x dan y
        x = Dx_10 /D_10
        y = Dy_10 /D_10
        print(f"Titik potong dari dua garis adalah: x = {x}, y = {y}")
        # Menyiapkan data untuk plotting
        x_vals_10 = np.linspace(-10, 10, 400)
        y_vals1_10 = (k_10 - i_10 * x_vals_10) / j_10
        y_vals2_10 = (n_10 - l_10 * x_vals_10) / m_10

        # Plot garis pertama
        plt.plot(x_vals_10, y_vals1_10, label=f'{i_10}x + {j_10}y = {k_10}')

        # Plot garis kedua
        plt.plot(x_vals_10, y_vals2_10, label=f'{l_10}x + {m_10}y = {n_10}')

        # Plot titik potong
        plt.plot(x, y, 'ro')  # 'ro' means red color, circle marker
        plt.text(x, y, f'({x:.2f}, {y:.2f})', fontsize=12, ha='right')

        # Menambahkan label dan judul
        plt.xlabel('x')
        plt.ylabel('y')
        plt.axhline(0, color='black',linewidth=0.5)
        plt.axvline(0, color='black',linewidth=0.5)
        plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
        plt.legend()
        plt.title('Grafik Dua Garis dan Titik Potongnya')

        # Menampilkan plot
        plt.show()

else:
  print("Mohon maaf, hanya terdapat 3 kasus saja. Mohon masukkan 1, 2 atau 3 saja ya!.")

print("==================================================TERIMA KASIH=================================================")
# Out:
# -----------------Mari mencari titik potong dari dua garis yang memenuhi salah satu dari ketiga kasus di bawah ini!-----------------
# Kasus berapakah yang kamu ingin kerjakan? 2
# Masukkan gradien dari garis pertama: 4
# Masukkan nilai x dari titik yang dilewati oleh garis pertama: 0
# Masukkan nilai y dari titik yang dilewati oleh garis pertama: 2
# Masukkan gradien dari garis kedua: 4
# Masukkan nilai x dari titik yang dilewati oleh garis kedua: 6
# Masukkan nilai y dari titik yang dilewati oleh garis kedua: 14
# Kedua garis tidak mungkin berpotongan, sehingga tidak akan terdapat solusi.
# ==================================================TERIMA KASIH=================================================
